# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/search?q=OPPO%20mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 5)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices  # Updated to include product prices
})

# Display or save the scraped data
df.head()  # Display the DataFrame
# Out:
# Warning: Mismatched data on page 1. Names: 24, Links: 24, Prices: 29
# Warning: Mismatched data on page 2. Names: 24, Links: 24, Prices: 29
# Warning: Mismatched data on page 3. Names: 24, Links: 24, Prices: 29
# Warning: Mismatched data on page 4. Names: 24, Links: 24, Prices: 29
#                                         Product_Name  \
# 0     (Refurbished) OPPO A77s (Starry Black, 128 GB)
# 1              (Refurbished) OPPO A17k (Blue, 64 GB)
# 2          (Refurbished) OPPO A17 (Lake Blue, 64 GB)
# 3  (Refurbished) OPPO Reno8 Pro 5G (Glazed Black,...
# 4         (Refurbished) OPPO A17k (Navy Blue, 64 GB)
#
#                                         Product_Link            Product_Price
# 0  https://www.flipkart.com/refurbished-oppo-a77s...   ₹9,699\n₹17,99946% off
# 1  https://www.flipkart.com/refurbished-oppo-a17k...   ₹4,599\n₹12,99964% off
# 2  https://www.flipkart.com/refurbished-oppo-a17-...   ₹7,999\n₹14,99946% off
# 3  https://www.flipkart.com/refurbished-oppo-reno...  ₹23,999\n₹52,99954% off
# 4  https://www.flipkart.com/refurbished-oppo-a17k...   ₹4,899\n₹12,99962% off

# %%
df.shape
# Out:
# (20, 3)

# %%
df
# Out:
#                                          Product_Name  \
# 0      (Refurbished) OPPO A77s (Starry Black, 128 GB)
# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&sid=tyy%2F4io&sort=recency_desc&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkxhdGVzdCBTYW1zdW5nIG1vYmlsZXMgIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&wid=1.productCard.PMU_V2_1&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax"
def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 20)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices  # Updated to include product prices
})

# Display or save the scraped data
df.head()  # Display the DataFrame
# Out:
#                                        Product_Name  \
# 0              SAMSUNG M55s (Thunder Black, 128 GB)
# 1           SAMSUNG Galaxy S24 FE 5G (Blue, 256 GB)
# 2           SAMSUNG Galaxy S24 FE 5G (Mint, 256 GB)
# 3       SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)
# 4  SAMSUNG SM-A356ELBJINS (Awesome Iceblue, 128 GB)
#
#                                         Product_Link           Product_Price
# 0  https://www.flipkart.com/samsung-m55s-thunder-...  ₹27,999\n₹28,9993% off
# 1  https://www.flipkart.com/samsung-galaxy-s24-fe...  ₹59,999\n₹65,9999% off
# 2  https://www.flipkart.com/samsung-galaxy-s24-fe...  ₹59,999\n₹65,9999% off
# 3  https://www.flipkart.com/samsung-galaxy-s24-fe...  ₹59,999\n₹65,9999% off
# 4  https://www.flipkart.com/samsung-sm-a356elbjin...  ₹30,899\n₹33,9999% off

# %%
df.shape
# Out:
# (448, 3)

# %%
df
# Out:
#                                          Product_Name  \
# 0                SAMSUNG M55s (Thunder Black, 128 GB)
# 1             SAMSUNG Galaxy S24 FE 5G (Blue, 256 GB)
# 2             SAMSUNG Galaxy S24 FE 5G (Mint, 256 GB)
# 3         SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)
# 4    SAMSUNG SM-A356ELBJINS (Awesome Iceblue, 128 GB)
# ..                                                ...
# 443    SAMSUNG Galaxy S8 Plus (Midnight Black, 64 GB)
# 444         SAMSUNG Galaxy S8 (Midnight Black, 64 GB)
# 445         SAMSUNG Galaxy A7-2017 (Gold Sand, 32 GB)
# 446          SAMSUNG Galaxy S7 (Gold Platinum, 32 GB)
# 447      SAMSUNG Galaxy Note 3 (Classic White, 32 GB)
#
#                                           Product_Link  \
# 0    https://www.flipkart.com/samsung-m55s-thunder-...
# 1    https://www.flipkart.com/samsung-galaxy-s24-fe...
# 2    https://www.flipkart.com/samsung-galaxy-s24-fe...
# 3    https://www.flipkart.com/samsung-galaxy-s24-fe...
# 4    https://www.flipkart.com/samsung-sm-a356elbjin...
# ..                                                 ...
# 443  https://www.flipkart.com/samsung-galaxy-s8-plu...
# 444  https://www.flipkart.com/samsung-galaxy-s8-mid...
# 445  https://www.flipkart.com/samsung-galaxy-a7-201...
# 446  https://www.flipkart.com/samsung-galaxy-s7-gol...
# 447  https://www.flipkart.com/samsung-galaxy-note-3...
#
#                Product_Price
# 0     ₹27,999\n₹28,9993% off
# 1     ₹59,999\n₹65,9999% off
# 2     ₹59,999\n₹65,9999% off
# 3     ₹59,999\n₹65,9999% off
# 4     ₹30,899\n₹33,9999% off
# ..                       ...
# 443   ₹53,990\n₹59,0008% off
# 444   ₹49,990\n₹51,0001% off
# 445  ₹25,900\n₹37,30030% off
# 446                  ₹46,000
# 447                  ₹43,092
#
# [448 rows x 3 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&sid=tyy%2F4io&sort=recency_desc&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkxhdGVzdCBTYW1zdW5nIG1vYmlsZXMgIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&wid=1.productCard.PMU_V2_1&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax"

def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 20)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices
})

# Save the DataFrame to a CSV file
df.to_csv('flipkart_samsung_products.csv', index=False)

print("Data saved to flipkart_samsung_products.csv")
# Out:
# Data saved to flipkart_samsung_products.csv

# %%
df=pd.read_csv('flipkart_samsung_products.csv')
df
# Out:
#                                          Product_Name  \
# 0                SAMSUNG M55s (Thunder Black, 128 GB)
# 1             SAMSUNG Galaxy S24 FE 5G (Blue, 256 GB)
# 2             SAMSUNG Galaxy S24 FE 5G (Mint, 256 GB)
# 3         SAMSUNG Galaxy S24 FE 5G (Graphite, 256 GB)
# 4    SAMSUNG SM-A356ELBJINS (Awesome Iceblue, 128 GB)
# ..                                                ...
# 453    SAMSUNG Galaxy S8 Plus (Midnight Black, 64 GB)
# 454         SAMSUNG Galaxy S8 (Midnight Black, 64 GB)
# 455         SAMSUNG Galaxy A7-2017 (Gold Sand, 32 GB)
# 456          SAMSUNG Galaxy S7 (Gold Platinum, 32 GB)
# 457      SAMSUNG Galaxy Note 3 (Classic White, 32 GB)
#
#                                           Product_Link  \
# 0    https://www.flipkart.com/samsung-m55s-thunder-...
# 1    https://www.flipkart.com/samsung-galaxy-s24-fe...
# 2    https://www.flipkart.com/samsung-galaxy-s24-fe...
# 3    https://www.flipkart.com/samsung-galaxy-s24-fe...
# 4    https://www.flipkart.com/samsung-sm-a356elbjin...
# ..                                                 ...
# 453  https://www.flipkart.com/samsung-galaxy-s8-plu...
# 454  https://www.flipkart.com/samsung-galaxy-s8-mid...
# 455  https://www.flipkart.com/samsung-galaxy-a7-201...
# 456  https://www.flipkart.com/samsung-galaxy-s7-gol...
# 457  https://www.flipkart.com/samsung-galaxy-note-3...
#
#                Product_Price
# 0     ₹27,999\n₹28,9993% off
# 1     ₹59,999\n₹65,9999% off
# 2     ₹59,999\n₹65,9999% off
# 3     ₹59,999\n₹65,9999% off
# 4     ₹30,899\n₹33,9999% off
# ..                       ...
# 453   ₹53,990\n₹59,0008% off
# 454   ₹49,990\n₹51,0001% off
# 455  ₹25,900\n₹37,30030% off
# 456                  ₹46,000
# 457                  ₹43,092
#
# [458 rows x 3 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/search?q=oppo+mobile+&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax"

def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 3)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices
})

# Save the DataFrame to a CSV file
df.to_csv('flipkart_oppo_products.csv', index=False)

print("Data saved to flipkart_oppo_products.csv")
# Out:
# Data saved to flipkart_oppo_products.csv

# %%
df=pd.read_csv('flipkart_oppo_products.csv')
df
# Out:
#                                          Product_Name  \
# 0           OPPO Reno 12 Pro 5G (Space Brown, 512 GB)
# 1   OPPO Reno 12 Pro 5G (Manish Malhotra Limited E...
# 2                OPPO F25 Pro 5G (Ocean Blue, 256 GB)
# 3                   OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 4                  OPPO F27 5G (Amber Orange, 256 GB)
# ..                                                ...
# 57                   OPPO A78 5G (Aqua Green, 128 GB)
# 58    (Refurbished) OPPO Reno10 5G (Ice Blue, 256 GB)
# 41  https://www.flipkart.com/oppo-f21s-pro-dawnlig...                  ₹27,999
# 42  https://www.flipkart.com/refurbished-oppo-reno...  ₹22,499\n₹34,99935% off
# 43  https://www.flipkart.com/refurbished-oppo-find...  ₹65,999\n₹99,99934% off
# 44  https://www.flipkart.com/oppo-a78-mist-black-1...         ₹22,998\n₹22,999
# 45  https://www.flipkart.com/oppo-a79-5g-mystery-b...   ₹21,999\n₹22,9994% off
# 46  https://www.flipkart.com/oppo-find-n2-flip-moo...  ₹89,999\n₹99,99910% off
# 47  https://www.flipkart.com/oppo-a79-5g-glowing-g...         ₹22,800\n₹22,999
# 48  https://www.flipkart.com/oppo-a78-5g-glowing-b...         ₹21,998\n₹21,999
# 49  https://www.flipkart.com/oppo-a78-5g-glowing-b...   ₹20,990\n₹21,9994% off
# 50  https://www.flipkart.com/oppo-find-n3-flip-cre...  ₹74,999\n₹99,99925% off
# 51  https://www.flipkart.com/oppo-a77-sunset-orang...                  ₹21,999
# 52  https://www.flipkart.com/oppo-reno10-5g-ice-bl...  ₹23,749\n₹38,99939% off
# 53  https://www.flipkart.com/oppo-f23-5g-bold-gold...  ₹22,999\n₹28,99920% off
# 54  https://www.flipkart.com/oppo-f21s-pro-starlig...                  ₹27,999
# 55  https://www.flipkart.com/oppo-f21-pro-5g-cosmi...                  ₹31,999
# 56  https://www.flipkart.com/oppo-f21-pro-5g-rainb...                  ₹31,999
# 57  https://www.flipkart.com/oppo-a78-5g-aqua-gree...                  ₹24,999
# 58  https://www.flipkart.com/refurbished-oppo-reno...  ₹21,999\n₹38,99943% off
# 59  https://www.flipkart.com/refurbished-oppo-reno...  ₹23,999\n₹52,99954% off
# 60  https://www.flipkart.com/refurbished-oppo-reno...  ₹27,599\n₹39,99931% off
# 61  https://www.flipkart.com/refurbished-oppo-reno...  ₹27,599\n₹44,99938% off

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/search?q=one+plus+mobile&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=one+plus+mobile%7CMobiles&requestId=8741fa14-4d57-4206-8ba5-d51181b6998f&as-backfill=on&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax"

def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 11)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices
})

# Save the DataFrame to a CSV file
df.to_csv('flipkart_oneplus_products.csv', index=False)

print("Data saved to flipkart_one_products.csv")
# Out:
# Data saved to flipkart_one_products.csv

# %%
df=pd.read_csv('flipkart_oneplus_products.csv')
df
# Out:
#                                           Product_Name  \
# 0    OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...
# 1      OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)
# 2      OnePlus Nord CE4 lite 5G (SUPER SILVER, 128 GB)
# 3      OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 128 GB)
# 4         OnePlus Nord CE4 lite 5G (MEGA BLUE, 256 GB)
# 5      OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 256 GB)
# 6            OnePlus Nord CE4 (Celadon Marble, 128 GB)
# 7               OnePlus Nord CE4 (Dark Chrome, 256 GB)
# 8               OnePlus Nord CE4 (Dark Chrome, 128 GB)
# 9            OnePlus Nord CE4 (Celadon Marble, 256 GB)
# 10     OnePlus Nord CE4 lite 5G (SUPER SILVER, 256 GB)
# 11        OnePlus Nord CE4 lite 5G (MEGA BLUE, 128 GB)
# 12                     OnePlus 12R (Iron Gray, 256 GB)
# 13            OnePlus 11R 5G (Galactic Silver, 256 GB)
# 14                OnePlus 11R 5G (Sonic Black, 128 GB)
# 15               OnePlus 11 5G (Eternal Green, 256 GB)
# 16               OnePlus 11 5G (Eternal Green, 128 GB)
# 17                 OnePlus 11 5G (Titan Black, 128 GB)
# 18                     OnePlus 12R (Iron Grey, 256 GB)
# 19                     OnePlus 12R (Cool Blue, 256 GB)
# 20            OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 21             OnePlus Nord 3 5G (Misty Green, 128 GB)
# 22          OnePlus Nord CE3 5G (Grey Shimmer, 128 GB)
# 23               OnePlus 11 5G (Eternal Green, 256 GB)
# 24                 OnePlus 11 5G (Titan Black, 128 GB)
# 25                OnePlus 11R 5G (Sonic Black, 256 GB)
# 26       OnePlus Nord 4 5G (Obsidian Midnight, 256 GB)
# 27        OnePlus Nord 4 5G (Mercurial Silver, 256 GB)
# 28       OnePlus Nord 4 5G (Obsidian Midnight, 128 GB)
# 29                  OnePlus 12 (Flowy Emerald, 256 GB)
# 30        OnePlus Nord 4 5G (Mercurial Silver, 256 GB)
# 31       OnePlus Nord 4 5G (Obsidian Midnight, 256 GB)
# 32                     OnePlus 12R (Cool Blue, 256 GB)
# 33                  OnePlus 10R (Forest Green, 128 GB)
# 34                  OnePlus 12 (Flowy Emerald, 512 GB)
# 35          OnePlus 10 Pro 5G (Emerald Forest, 128 GB)
# 36                  OnePlus 10R (Forest Green, 128 GB)
# 37             OnePlus Nord 4 5G (Oasis Green, 256 GB)
# 38            OnePlus 11R 5G (Galactic Silver, 128 GB)
# 39                    OnePlus 12 (Silky Black, 512 GB)
# 40          OnePlus 10 Pro 5G (Volcanic Black, 128 GB)
# 41            OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 42                  OnePlus 12 (Glacial White, 256 GB)
# 43                 OnePlus 11 5G (Titan Black, 256 GB)
# 44                 OnePlus 9 5G (Astral Black, 128 GB)
# 45          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)
# 46                   OnePlus 12R (Sunset Dune, 256 GB)
# 47                   OnePlus 9 5G (Arctic Sky, 256 GB)
# 48            OnePlus 10T 5G (Moonstone Black, 256 GB)
# 49               OnePlus Nord 2T 5G (Jade Fog, 128 GB)
# 50                OnePlus 9R 5G (Carbon Black, 256 GB)
# 51            OnePlus 10T 5G (Moonstone Black, 128 GB)
# 52                OnePlus 9R 5G (Carbon Black, 128 GB)
# 53                 OnePlus 10T 5G (Jade Green, 128 GB)
# 54               OnePlus Nord 2T 5G (Jade Fog, 256 GB)
# 55                  OnePlus 10R (Sierra Black, 128 GB)
# 56              OnePlus 11 5G (Marble Odyssey, 256 GB)
# 57                OnePlus Open (Voyager Black, 512 GB)
# 58                 OnePlus Open (Emerald Dusk, 512 GB)
# 59                OnePlus 8T 5G (Lunar Silver, 128 GB)
# 60                  OnePlus 10R (Sierra Black, 128 GB)
# 61             OnePlus Nord 2 5G (Gray Sierra, 128 GB)
# 62               OnePlus Nord 2T 5G (Jade Fog, 128 GB)
# 63            OnePlus 8T 5G (Aquamarine Green, 128 GB)
# 64               OnePlus 10R 5G (Sierra Black, 256 GB)
# 65                  OnePlus 10R (Forest Green, 128 GB)
# 66   (Refurbished) OnePlus 10T 5G (Jade Green, 128 GB)
# 67    (Refurbished) OnePlus 10R (Sierra Black, 128 GB)
# 68   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...
# 69     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)
# 70                 OnePlus 11 5G (Titan Black, 256 GB)
# 71             OnePlus Nord 3 5G (Misty Green, 256 GB)
# 72                   OnePlus 12R (Sunset Dune, 256 GB)
# 73             OnePlus 11R 5G (Red, Solar Red, 128 GB)
# 74                     OnePlus 12R (Iron Gray, 128 GB)
# 75                     OnePlus 12R (Cool Blue, 128 GB)
# 76            OnePlus Nord 3 5G (Tempest Gray, 256 GB)
# 77                  OnePlus 11R 5G (SOLAR RED, 256 GB)
# 78                  OnePlus 11R 5G (Solar Red, 512 GB)
# 79            OnePlus Nord CE3 5G (Aqua Surge, 128 GB)
# 80          OnePlus Nord CE3 5G (Grey Shimmer, 256 GB)
# 81            OnePlus Nord CE3 5G (Aqua Surge, 256 GB)
# 82               OnePlus 11 5G (Eternal Green, 128 GB)
# 83             OnePlus Nord 4 5G (Oasis Green, 128 GB)
# 84        OnePlus Nord 4 5G (Mercurial Silver, 128 GB)
# 85      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 86                    OnePlus 12 (Silky Black, 256 GB)
# 87             OnePlus Nord 2 5G (Gray Sierra, 128 GB)
# 88                   OnePlus 12R (Sunset Dune, 128 GB)
# 89                   OnePlus 9 5G (Arctic Sky, 128 GB)
# 90          OnePlus 10 Pro 5G (Emerald Forest, 128 GB)
# 91            OnePlus Nord 2T 5G (Gray Shadow, 256 GB)
# 92                 OnePlus 9 5G (Astral Black, 256 GB)
# 93                   OnePlus 9 5G (Arctic Sky, 256 GB)
# 94          OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)
# 95          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)
# 96               OnePlus Nord 2T 5G (Jade Fog, 128 GB)
# 97          OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)
# 98          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)
# 99                  OnePlus 9 5G (Winter Mist, 256 GB)
# 100                  OnePlus 9 5G (Arctic Sky, 128 GB)
# 101           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 102            OnePlus Nord 4 5G (Oasis Green, 256 GB)
# 103              OnePlus Nord 2 5G (Blue Haze, 128 GB)
# 104              OnePlus 10R 5G (Forest Green, 256 GB)
# 105           OnePlus 10T 5G (Moonstone Black, 256 GB)
# 106                    OnePlus Nord (Gray Ash, 256 GB)
# 107                  OnePlus 9R 5G (Lake Blue, 128 GB)
# 108                   OnePlus Nord (Gray Onyx, 128 GB)
# 109                 OnePlus Nord (Blue Marble, 128 GB)
# 110              OnePlus Nord 2 5G (Blue Haze, 256 GB)
# 111         OnePlus 10 Pro 5G (Emerald Forest, 256 GB)
# 112           OnePlus 9 Pro 5G (Stellar Black, 256 GB)
# 113                 OnePlus 10R (Forest Green, 256 GB)
# 114                   OnePlus Nord (Gray Onyx, 256 GB)
# 115                 OnePlus Nord (Blue Marble, 256 GB)
# 116              OnePlus Nord 2T 5G (Jade Fog, 128 GB)
# 117           OnePlus 9 Pro 5G (Stellar Black, 128 GB)
# 118            OnePlus 9 Pro 5G (Morning Mist, 128 GB)
# 119           OnePlus Nord 2T 5G (Gray Shadow, 256 GB)
# 120           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 121                  OnePlus 7T (Glacier Blue, 256 GB)
# 122                OnePlus 7T (Frosted Silver, 256 GB)
# 123              OnePlus 9 Pro 5G (Pine Green, 256 GB)
# 124                OnePlus 9 5G (Astral Black, 256 GB)
# 125                OnePlus 10R 5G (Prime Blue, 128 GB)
# 126           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 127                OnePlus 9 5G (Astral Black, 128 GB)
# 201      ₹38,392\n₹42,99910% off
# 202       ₹28,999\n₹30,9996% off
# 203      ₹34,999\n₹42,99918% off
# 204      ₹34,999\n₹59,99941% off
# 205       ₹39,800\n₹42,9997% off
# 206      ₹34,999\n₹49,99930% off
# 207      ₹34,890\n₹44,99922% off
# 208                      ₹59,999
# 209       ₹23,499\n₹23,9992% off
# 210      ₹27,999\n₹52,99947% off
# 211      ₹35,999\n₹49,99928% off
# 212                      ₹29,999
# 213      ₹27,999\n₹52,99947% off
# 214      ₹29,999\n₹57,99948% off
# 215      ₹33,980\n₹48,99930% off
# 216      ₹32,980\n₹44,99926% off
# 217      ₹32,990\n₹49,99934% off
# 218      ₹30,899\n₹38,99920% off
# 219       ₹32,500\n₹33,9994% off
# 220      ₹32,990\n₹49,99934% off
# 221       ₹41,000\n₹42,9994% off
# 222      ₹34,999\n₹42,99918% off
# 223      ₹39,990\n₹49,99920% off
# 224      ₹43,619\n₹49,99912% off
# 225      ₹43,619\n₹50,99914% off
# 226       ₹42,899\n₹47,5899% off
# 227      ₹37,999\n₹51,99926% off
# 228      ₹34,999\n₹58,99940% off
# 229                      ₹49,999
# 230                      ₹40,988
# 231       ₹25,999\n₹27,9997% off
# 232                      ₹40,999
# 233                      ₹37,190
# 234                      ₹49,999
# 235      ₹29,990\n₹41,99928% off
# 236      ₹34,999\n₹42,99918% off
# 237      ₹29,999\n₹54,99945% off
# 238      ₹32,999\n₹37,99913% off
# 239      ₹24,499\n₹44,99945% off
# 240      ₹28,999\n₹54,99947% off
# 241      ₹35,399\n₹44,99921% off
# 242      ₹23,999\n₹44,99946% off
# 243      ₹25,999\n₹49,99948% off
# 244      ₹21,499\n₹45,99953% off
# 245      ₹21,999\n₹38,99943% off
# 246      ₹21,499\n₹45,99953% off

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3Dvivo&otracker=nmenu_sub_Electronics_0_Vivo&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax"

def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 11)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices
})

# Save the DataFrame to a CSV file
df.to_csv('flipkart_vivo_products.csv', index=False)

print("Data saved to flipkart_vivo_products.csv")
# Out:
# Data saved to flipkart_vivo_products.csv

# %%
df=pd.read_csv('flipkart_vivo_products.csv')
df
# Out:
#                                         Product_Name  \
# 0                vivo T3 Ultra (Frost Green, 256 GB)
# 1            vivo V30 Pro 5G (Classic Black, 256 GB)
# 2                   vivo T3 5G (Cosmic Blue, 256 GB)
# 3          vivo T3 Pro 5G (Sandstone Orange, 256 GB)
# 4             vivo T3 Pro 5G (Emerald Green, 256 GB)
# ..                                               ...
# 227              vivo X60 Pro (Shimmer Blue, 256 GB)
# 228  (Refurbished) vivo X90 (Asteroid Black, 256 GB)
# 229           vivo V20 SE (Aquamarine Green, 128 GB)
# 230               vivo S1 Pro (Dreamy White, 128 GB)
# 231     (Refurbished) vivo X90 (Breeze Blue, 256 GB)
#
#                                           Product_Link  \
# 0    https://www.flipkart.com/vivo-t3-ultra-frost-g...
# 1    https://www.flipkart.com/vivo-v30-pro-5g-class...
# 2    https://www.flipkart.com/vivo-t3-5g-cosmic-blu...
# 3    https://www.flipkart.com/vivo-t3-pro-5g-sandst...
# 4    https://www.flipkart.com/vivo-t3-pro-5g-emeral...
# ..                                                 ...
# 227  https://www.flipkart.com/vivo-x60-pro-shimmer-...
# 228  https://www.flipkart.com/refurbished-vivo-x90-...
# 229  https://www.flipkart.com/vivo-v20-se-aquamarin...
# 230  https://www.flipkart.com/vivo-s1-pro-dreamy-wh...
# 231  https://www.flipkart.com/refurbished-vivo-x90-...
#
#                Product_Price
# 0    ₹33,999\n₹37,99910% off
# 1    ₹38,999\n₹46,99917% off
# 2    ₹20,499\n₹24,99918% off
# 3    ₹26,999\n₹31,99915% off
# 4    ₹26,999\n₹31,99915% off
# ..                       ...
# 227                  ₹54,990
# 228  ₹40,099\n₹61,99935% off
# 229                  ₹24,990
# 230                  ₹20,990
# 231  ₹38,199\n₹61,99938% off
#
# [232 rows x 3 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/mobiles/mi~brand/pr?sid=tyy%2C4io&otracker=nmenu_sub_Electronics_0_Mi&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax"

def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 7)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices
})

# Save the DataFrame to a CSV file
df.to_csv('flipkart_redmi_products.csv', index=False)

print("Data saved to flipkart_redmi_products.csv")
# Out:
# Data saved to flipkart_redmi_products.csv

# %%
df=pd.read_csv('flipkart_redmi_products.csv')
df
# Out:
#                                         Product_Name  \
# 0              Xiaomi 14 CIVI (Matcha Green, 256 GB)
# 1              Xiaomi 14 CIVI (Shadow Black, 512 GB)
# 2              Xiaomi 14 CIVI (Shadow Black, 256 GB)
# 3               Xiaomi 14 CIVI (Cruise Blue, 256 GB)
# 4              Xiaomi 14 CIVI (Matcha Green, 512 GB)
# ..                                               ...
# 156                               Mi 5 (Gold, 32 GB)
# 157                            Mi A2 (Black, 128 GB)
# 158  Xiaomi 11i Hypercharge 5G (Purple Mist, 128 GB)
# 159                    Mi 10 (Twilight Grey, 256 GB)
# 160             MI 11X 5G (CELESTIAL SILVER, 128 GB)
#
#                                           Product_Link  \
# 0    https://www.flipkart.com/xiaomi-14-civi-matcha...
# 1    https://www.flipkart.com/xiaomi-14-civi-shadow...
# 2    https://www.flipkart.com/xiaomi-14-civi-shadow...
# 3    https://www.flipkart.com/xiaomi-14-civi-cruise...
# 4    https://www.flipkart.com/xiaomi-14-civi-matcha...
# ..                                                 ...
# 156  https://www.flipkart.com/mi-5-gold-32-gb/p/itm...
# 157  https://www.flipkart.com/mi-a2-black-128-gb/p/...
# 158  https://www.flipkart.com/xiaomi-11i-hypercharg...
# 159  https://www.flipkart.com/mi-10-twilight-grey-2...
# 160  https://www.flipkart.com/mi-11x-5g-celestial-s...
#
#                Product_Price
# 0    ₹40,999\n₹54,99925% off
# 1    ₹45,999\n₹59,99923% off
# 2    ₹40,999\n₹54,99925% off
# 3    ₹40,999\n₹54,99925% off
# 4    ₹45,999\n₹59,99923% off
# ..                       ...
# 156                  ₹24,999
# 157                  ₹20,500
# 158  ₹28,999\n₹33,99914% off
# 159                  ₹59,999
# 160                  ₹24,999
#
# [161 rows x 3 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/search?q=google+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_10_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_10_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=google+mobiles%7CMobiles&requestId=9e9b271d-a21b-40b6-8334-857c7f6d013c&as-backfill=on&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax"
def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, 2)  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices
})

# Save the DataFrame to a CSV file
df.to_csv('flipkart_redmi_products.csv', index=False)

print("Data saved to flipkart_redmi_products.csv")
# Out:
# Data saved to flipkart_redmi_products.csv

# %%
df=pd.read_csv('flipkart_redmi_products.csv')
df
# Out:
#                                          Product_Name  \
# 0                  Google Pixel 7a (Charcoal, 128 GB)
# 1                      Google Pixel 7a (Snow, 128 GB)
# 2                     Google Pixel 7a (Coral, 128 GB)
# 3                      Google Pixel 8 (Hazel, 128 GB)
# 4                   Google Pixel 8 (Obsidian, 128 GB)
# 5                      Google Pixel 8 (Hazel, 256 GB)
# 6                       Google Pixel 8 (Mint, 128 GB)
# 7                       Google Pixel 8 (Rose, 128 GB)
# 8                  Google Pixel 9 (Porcelain, 256 GB)
# 9                   Google Pixel 9 (Obsidian, 256 GB)
# 10               Google Pixel 9 (Wintergreen, 256 GB)
# 11                Google Pixel 8a (Porcelain, 128 GB)
# 12                     Google Pixel 9 (Peony, 256 GB)
# 13                      Google Pixel 8a (Bay, 128 GB)
# 14              Google Pixel 9 Pro XL (Hazel, 256 GB)
# 15          Google Pixel 9 Pro XL (Porcelain, 256 GB)
# 16           Google Pixel 9 Pro XL (Obsidian, 256 GB)
# 17                 Google Pixel 8a (Obsidian, 128 GB)
# 18                     Google Pixel 8a (Aloe, 128 GB)
# 19                  Google Pixel 7 (Obsidian, 128 GB)
# 20                      Google Pixel 7 (Snow, 128 GB)
# 21                Google Pixel 7 (Lemongrass, 128 GB)
# 22        Google Pixel 9 Pro XL (Rose Quartz, 256 GB)
# 23           Google Pixel 9 Pro XL (Obsidian, 512 GB)
# 24         Google Pixel 9 Pro Fold (Obsidian, 256 GB)
# 25              Google Pixel 7 Pro (Obsidian, 128 GB)
# 26                 Google Pixel 7 Pro (Hazel, 128 GB)
# 27              Google Pixel 8 Pro (Obsidian, 128 GB)
# 28                   Google Pixel 8 Pro (Bay, 128 GB)
# 29              Google Pixel 8 Pro (Obsidian, 256 GB)
# 30       (Refurbished) Google Pixel 7a (Snow, 128 GB)
# 31                 Google Pixel 6a (Charcoal, 128 GB)
# 32                    Google Pixel 6a (Chalk, 128 GB)
# 33     (Refurbished) Google Pixel 8 Pro (Bay, 128 GB)
# 34   (Refurbished) Google Pixel 7a (Charcoal, 128 GB)
# 35        (Refurbished) Google Pixel 7 (Snow, 128 GB)
# 36                  Google Pixel 7 Pro (Snow, 128 GB)
# 37        (Refurbished) Google Pixel 7a (Sea, 128 GB)
# 38  (Refurbished) Google Pixel 8 Pro (Obsidian, 12...
# 39   (Refurbished) Google Pixel 7 Pro (Hazel, 128 GB)
# 40                  Google Pixel 3 (Not Pink, 128 GB)
# 41        (Refurbished) Google Pixel 8 (Mint, 128 GB)
# 42       (Refurbished) Google Pixel 8 (Hazel, 256 GB)
# 43  (Refurbished) Google Pixel 8 Pro (Obsidian, 25...
# 44  (Refurbished) Google Pixel 7 (Lemongrass, 128 GB)
# 45    (Refurbished) Google Pixel 7 (Obsidian, 128 GB)
# 46  (Refurbished) Google Pixel 4a (Just Black, 128...
#
#                                          Product_Link  \
# 0   https://www.flipkart.com/google-pixel-7a-charc...
# 1   https://www.flipkart.com/google-pixel-7a-snow-...
# 2   https://www.flipkart.com/google-pixel-7a-coral...
# 3   https://www.flipkart.com/google-pixel-8-hazel-...
# 4   https://www.flipkart.com/google-pixel-8-obsidi...
# 5   https://www.flipkart.com/google-pixel-8-hazel-...
# 6   https://www.flipkart.com/google-pixel-8-mint-1...
# 7   https://www.flipkart.com/google-pixel-8-rose-1...
# 8   https://www.flipkart.com/google-pixel-9-porcel...
# 9   https://www.flipkart.com/google-pixel-9-obsidi...
# 10  https://www.flipkart.com/google-pixel-9-winter...
# 29  ₹93,999\n₹1,13,99917% off
# 30    ₹29,499\n₹43,99932% off
# 31                    ₹43,999
# 32                    ₹43,999
# 33  ₹84,999\n₹1,06,99920% off
# 34    ₹29,499\n₹43,99932% off
# 35    ₹33,999\n₹59,99943% off
# 36    ₹44,999\n₹84,99947% off
# 37    ₹29,499\n₹43,99932% off
# 38  ₹84,999\n₹1,06,99920% off
# 39    ₹48,999\n₹84,99942% off
# 40                    ₹80,000
# 41    ₹52,999\n₹96,99945% off
# 42    ₹58,999\n₹79,99926% off
# 43  ₹89,999\n₹1,06,99915% off
# 44    ₹33,999\n₹75,99955% off
# 45    ₹33,999\n₹75,99955% off
# 46    ₹20,999\n₹34,99940% off

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# URL of the website
url = "https://www.flipkart.com/search?q=apple+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=apple+mobiles%7CMobiles&requestId=74513d15-9fcc-41ea-a7e0-16499e689ee3&as-backfill=on&otracker=nmenu_sub_Electronics_0_Apple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&p%5B%5D=facets.brand%255B%255D%3DApple"
def initialize_driver():
    driver = webdriver.Chrome()  # Ensure ChromeDriver is in your PATH
    driver.maximize_window()
    return driver

def load_page(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

# Function to scrape product names, links, and prices
def scrape_product_data(driver):
    product_names = [name.text for name in driver.find_elements(By.CLASS_NAME, 'KzDlHZ')]
    product_links = [link.get_attribute('href') for link in driver.find_elements(By.XPATH, '//a[@class="CGtC98"]')]
    product_prices = [price.text for price in driver.find_elements(By.CLASS_NAME, 'hl05eU')]  # Adjusted class name for prices
    
    # Return product data
    return product_names, product_links, product_prices

# Function to scrape multiple pages
def scrape_multiple_pages(driver, base_url, num_pages):
    all_product_names = []
    all_product_links = []
    all_product_prices = []
    
    for page in range(1, num_pages + 1):
        load_page(driver, f"{base_url}&page={page}")  # Update the URL to include the page number
        product_names, product_links, product_prices = scrape_product_data(driver)
        
        # Ensure the lists are of the same length before extending
        if len(product_names) == len(product_links) == len(product_prices):
            all_product_names.extend(product_names)
            all_product_links.extend(product_links)
            all_product_prices.extend(product_prices)
        else:
            print(f"Warning: Mismatched data on page {page}. Names: {len(product_names)}, Links: {len(product_links)}, Prices: {len(product_prices)}")

        time.sleep(5)  # Wait before loading the next page
    
    return all_product_names, all_product_links, all_product_prices

# Initialize WebDriver and scrape multiple pages
driver = initialize_driver()
all_product_names, all_product_links, all_product_prices = scrape_multiple_pages(driver, url, )  # Adjust number of pages as needed

# Close the driver
driver.quit()

# Create a DataFrame to store the results
df = pd.DataFrame({
    'Product_Name': all_product_names,
    'Product_Link': all_product_links,
    'Product_Price': all_product_prices
})

# Save the DataFrame to a CSV file
df.to_csv('flipkart_redmi_products.csv', index=False)

print("Data saved to flipkart_redmi_products.csv")
